# %% [markdown]
# ## Finds
# ```
# f(x) = x-cos(x)
# ```
# roots using Bisection, Secant, and Newton Raphson

# %%
from math import cos, sin

# %% [markdown]
# ## 1. Inisialisasi Fungsi `Bisection`, `Secant`, dan `Newton Raphson`

# %% [markdown]
# ### a. Metode Bisection

# %%
# Fungsi rumus Bisection
def bisectionMethod(pers, a, b, eps):
    # Terjemahkan input persamaan dari user ke dalam fungsi f(x)
    def f(x):
        return eval(pers, {"x": x, "cos": cos, "sin": sin})

    i = 0
    while True:
        i = i + 1  # hitung iterasi
        c = (a + b) / 2  # hitung titik tengah c
        print(
            "Iterasi " + str(i) + f": [{a:.14f}" + f", {b:.14f}" + f"], c ≈ {c:.14f}"
        )  # cetak iterasi

        if f(c) == 0:  # jika c adalah akar persamaan
            print("======================")
            print(f"Hampiran akar x ≈ {c:.14f}" + " pada iterasi ke-" + str(i))
            break

        elif f(a) * f(c) < 0:  # jika akar berada di interval [a, c]
            b = c  # perbarui b menjadi c
        else:  # jika akar berada di interval [c, b]
            a = c  # perbarui a menjadi c

        if abs(b - a) < eps:  # cek apakah interval sudah lebih kecil dari epsilon
            print("======================")
            print(f"Hampiran akar x ≈ {c:.14f}" + " pada iterasi ke-" + str(i))
            break

# %% [markdown]
# ### b. Metode Secant

# %%
# Fungsi rumus Secant
def Secant(pers, x0, x1, eps):
    # Terjemahkan input persamaan dari user ke dalam fungsi f(x)
    def f(x):
        return eval(pers, {"x": x, "cos": cos, "sin": sin})

    x_oldbanget = x0  # simpan x0 sebagai x_oldbanget (xi-1)
    x_old = x1  # simpan x1 sebagai x_old (xi)
    i = 0
    print("x" + str(i) + " ≈ " + str(x0))  # cetak x0
    print("x" + str(i + 1) + " ≈ " + str(x1))  # cetak x1

    # Lakukan iterasi untuk xi
    while True:
        i = i + 1  # hitung iterasi
        # hitung xi baru (xi+1)
        xi = x_old - (f(x_old) / (f(x_old) - f(x_oldbanget))) * (x_old - x_oldbanget)
        print("x" + str(i) + f" ≈ {xi:.14f}")  # cetak akar ke-i dengan 14 digit
        Er = abs(xi - x_old)  # perbarui galat

        # Cek apakah galat sudah di bawah epsilon
        if Er < eps:
            break

        # Jika belum, jadikan xi sebagai x_old
        # repeat iterasi
        x_oldbanget = x_old
        x_old = xi

    print("======================")
    print(f"Hampiran akar x ≈ {xi:.14f}" + " pada iterasi ke-" + str(i))

# %% [markdown]
# ### c. Metode Newton-Raphson

# %%
# Fungsi rumus Newton Raphson
def newtonRaph(pers, x0, eps):
    # Terjemahkan input persamaan dari user ke dalam fungsi f(x)
    def f(x):
        return eval(pers, {"x": x, "cos": cos, "sin": sin})

    # Turunan menggunakan numerical approximation
    def df(x, h=1e-6):
        return (f(x + h) - f(x - h)) / (2 * h)

    x_old = x0  # simpan x0 sebagai x_old
    i = 0
    print("x" + str(i) + " ≈ " + str(x0))  # cetak x0

    # Lakukan iterasi untuk xi
    while True:
        i = i + 1  # hitung iterasi
        xi = x_old - (f(x_old) / df(x_old))  # hitung xi baru
        print("x" + str(i) + f" ≈ {xi:.14f}")  # cetak akar ke-i dengan 14 digit
        Er = abs(xi - x_old)  # perbarui galat

        # Cek apakah galat sudah di bawah epsilon
        if Er < eps:
            break
        # Jika belum, jadikan xi sebagai x_old
        # repeat iterasi
        x_old = xi

    print("======================")
    print(f"Hampiran akar x ≈ {xi:.14f}" + " pada iterasi ke-" + str(i))

# %% [markdown]
# ## 2. Masukkan input persamaan
# ```
# f(x) = x-cos(x) lalu a = 0.6 dan b = 0.8
# ```
# sebagai input agar dapat diselesaikan menggunakan metode-metode diatas

# %%
# --- Interactive part ---
pers = input("Masukkan persamaan x (contoh, 'x-cos(x)'): ")
a = float(input("Masukkan nilai a(x0): "))
b = float(input("Masukkan nilai b(x1): "))
eps = float(input("Masukkan galat epsilon (contoh, 1e-6): "))

# Variabel Secant & Newton-Raph
x0 = a
x1 = b
# Out:
# Masukkan persamaan x (contoh, 'x - cos(x)'):  x-cos(x)
# Masukkan nilai a(x0):  0.6
# Masukkan nilai b(x1):  0.8
# Masukkan galat epsilon (contoh, 1e-6):  1e-6

# %%
# Panggil Fungsi
bisectionMethod(pers, a, b, eps)
# Out:
# Iterasi 1: [0.60000000000000, 0.80000000000000], c ≈ 0.70000000000000
# Iterasi 2: [0.70000000000000, 0.80000000000000], c ≈ 0.75000000000000
# Iterasi 3: [0.70000000000000, 0.75000000000000], c ≈ 0.72500000000000
# Iterasi 4: [0.72500000000000, 0.75000000000000], c ≈ 0.73750000000000
# Iterasi 5: [0.73750000000000, 0.75000000000000], c ≈ 0.74375000000000
# Iterasi 6: [0.73750000000000, 0.74375000000000], c ≈ 0.74062500000000
# Iterasi 7: [0.73750000000000, 0.74062500000000], c ≈ 0.73906250000000
# Iterasi 8: [0.73906250000000, 0.74062500000000], c ≈ 0.73984375000000
# Iterasi 9: [0.73906250000000, 0.73984375000000], c ≈ 0.73945312500000
# Iterasi 10: [0.73906250000000, 0.73945312500000], c ≈ 0.73925781250000
# Iterasi 11: [0.73906250000000, 0.73925781250000], c ≈ 0.73916015625000
# Iterasi 12: [0.73906250000000, 0.73916015625000], c ≈ 0.73911132812500
# Iterasi 13: [0.73906250000000, 0.73911132812500], c ≈ 0.73908691406250
# Iterasi 14: [0.73906250000000, 0.73908691406250], c ≈ 0.73907470703125
# Iterasi 15: [0.73907470703125, 0.73908691406250], c ≈ 0.73908081054688
# Iterasi 16: [0.73908081054688, 0.73908691406250], c ≈ 0.73908386230469
# Iterasi 17: [0.73908386230469, 0.73908691406250], c ≈ 0.73908538818359
# Iterasi 18: [0.73908386230469, 0.73908538818359], c ≈ 0.73908462524414
# ======================
# Hampiran akar x ≈ 0.73908462524414 pada iterasi ke-18

# %%
# Panggil Fungsi
Secant(pers, x0, x1, eps)
# Out:
# x0 ≈ 0.6
# x1 ≈ 0.8
# x1 ≈ 0.73713681973530
# x2 ≈ 0.73905972950106
# x3 ≈ 0.73908514415511
# x4 ≈ 0.73908513321510
# ======================
# Hampiran akar x ≈ 0.73908513321510 pada iterasi ke-4

# %%
# Panggil Fungsi
newtonRaph(pers, x0, eps)
# Out:
# x0 ≈ 0.6
# x1 ≈ 0.74401731943882
# x2 ≈ 0.73909047688625
# x3 ≈ 0.73908513322147
# x4 ≈ 0.73908513321516
# ======================
# Hampiran akar x ≈ 0.73908513321516 pada iterasi ke-4
